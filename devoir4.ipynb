# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as mp

# %%
pd.options.display.float_format"{:.2f}".format
# Out:
#   File "<ipython-input-4-1f9690c1ce05>", line 1
#     pd.options.display.float_format"{:.2f}".format
#                                           ^
# SyntaxError: invalid syntax

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
sub = pd.read_csv("grants.csv")
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (2,4,5,7,8,10,12,13,14,16,17,20,21,22,24,25,27,28,29,30,32,33,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sub.types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-1fd9e6f7b034> in <module>
# ----> 1 sub.types
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %%
sub = pd.read_csv("grants.csv")
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (2,4,5,7,8,10,12,13,14,16,17,20,21,22,24,25,27,28,29,30,32,33,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sub.dtypes
# Out:
# ref_number                     object
# amendment_number                int64
# amendment_date                 object
# agreement_type                 object
# recipient_type                 object
# recipient_business_number      object
# recipient_legal_name           object
# recipient_operating_name       object
# research_organization_name     object
# recipient_country              object
# recipient_province             object
# recipient_city                 object
# recipient_postal_code          object
# federal_riding_name_en         object
# federal_riding_name_fr         object
# federal_riding_number         float64
# prog_name_en                   object
# prog_name_fr                   object
# prog_purpose_en                object
# prog_purpose_fr                object
# agreement_title_en             object
# agreement_title_fr             object
# agreement_number               object
# agreement_value                object
# foreign_currency_type          object
# ...

# %%
md
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5003f0045998> in <module>
# ----> 1 md
#
# NameError: name 'md' is not defined

# %%
sub
# Out:
#                        ref_number  amendment_number amendment_date  \
# 0                GC-2017-Q1-00001                 0            NaN
# 1                GC-2017-Q1-00002                 0            NaN
# 2                GC-2017-Q1-00003                 0            NaN
# 3                GC-2017-Q1-00004                 0            NaN
# 4                GC-2017-Q1-00005                 0            NaN
# 5                GC-2017-Q1-00006                 0            NaN
# 6                GC-2017-Q1-00007                 0            NaN
# 7                GC-2017-Q1-00008                 0            NaN
# 8                GC-2017-Q2-00004                 0            NaN
# 9                GC-2017-Q1-00009                 0            NaN
# 10               GC-2017-Q1-00010                 0            NaN
# 11               GC-2017-Q1-00011                 0            NaN
# 12               GC-2017-Q1-00012                 0            NaN
# ...

# %%
sub.shape
# Out:
# (228964, 38)

# %%
sub = sub.drop("description_en, expected_results_en, additional_information_en", 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-4933c19c86de> in <module>
# ----> 1 sub = sub.drop("description_en, expected_results_en, additional_information_en", 1)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
sub = sub.drop("description_en", 1)

# %%
sub.columns
# Out:
# Index(['ref_number', 'amendment_number', 'amendment_date', 'agreement_type',
#        'recipient_type', 'recipient_business_number', 'recipient_legal_name',
#        'recipient_operating_name', 'research_organization_name',
#        'recipient_country', 'recipient_province', 'recipient_city',
#        'recipient_postal_code', 'federal_riding_name_en',
#        'federal_riding_name_fr', 'federal_riding_number', 'prog_name_en',
#        'prog_name_fr', 'prog_purpose_en', 'prog_purpose_fr',
#        'agreement_title_en', 'agreement_title_fr', 'agreement_number',
#        'agreement_value', 'foreign_currency_type', 'foreign_currency_value',
#        'agreement_start_date', 'agreement_end_date', 'coverage',
#        'description_fr', 'naics_identifier', 'expected_results_en',
#        'expected_results_fr', 'additional_information_en',
#        'additional_information_fr', 'owner_org', 'owner_org_title'],
#       dtype='object')

# %%
sub = sub.drop("expected_results_en", 1)

# %%
sub = sub.drop("additional_information_en", 1)

# %%
sub.columns
# Out:
# Index(['ref_number', 'amendment_number', 'amendment_date', 'agreement_type',
#        'recipient_type', 'recipient_business_number', 'recipient_legal_name',
#        'recipient_operating_name', 'research_organization_name',
#        'recipient_country', 'recipient_province', 'recipient_city',
#        'recipient_postal_code', 'federal_riding_name_en',
#        'federal_riding_name_fr', 'federal_riding_number', 'prog_name_en',
#        'prog_name_fr', 'prog_purpose_en', 'prog_purpose_fr',
#        'agreement_title_en', 'agreement_title_fr', 'agreement_number',
#        'agreement_value', 'foreign_currency_type', 'foreign_currency_value',
#        'agreement_start_date', 'agreement_end_date', 'coverage',
#        'description_fr', 'naics_identifier', 'expected_results_fr',
#        'additional_information_fr', 'owner_org', 'owner_org_title'],
#       dtype='object')

# %%
sub = sub.drop("prog_purpose_en", 1)

# %%
sub = sub.drop("federal_riding_name_en" 1)
# Out:
#   File "<ipython-input-20-3fd1f40259f9>", line 1
#     sub = sub.drop("federal_riding_name_en" 1)
#                                             ^
# SyntaxError: invalid syntax

# %%
sub = sub.drop("federal_riding_name_en", 1)

# %%
sub.columns
# Out:
# Index(['ref_number', 'amendment_number', 'amendment_date', 'agreement_type',
#        'recipient_type', 'recipient_business_number', 'recipient_legal_name',
#        'recipient_operating_name', 'research_organization_name',
#        'recipient_country', 'recipient_province', 'recipient_city',
#        'recipient_postal_code', 'federal_riding_name_fr',
#        'federal_riding_number', 'prog_name_en', 'prog_name_fr',
#        'prog_purpose_fr', 'agreement_title_en', 'agreement_title_fr',
#        'agreement_number', 'agreement_value', 'foreign_currency_type',
#        'foreign_currency_value', 'agreement_start_date', 'agreement_end_date',
#        'coverage', 'description_fr', 'naics_identifier', 'expected_results_fr',
#        'additional_information_fr', 'owner_org', 'owner_org_title'],
#       dtype='object')

# %%
sub = sub.columns['num_référence', 'num_amendement', 'date_amendement', 'type_entente',
       'type_bénéficiaire', 'num_entreprise_beneficiaire', 'nom_legal_beneficiaire',
       'nom_operation_beneficiaire', 'nom_organisation_recherche',
       'pays_beneficiaire', 'province_beneficiaire', 'ville_beneficiaire',
       'code_postal_beneficiaire', 'nom_circonscription_federale',
       'num_circonscription_federale', 'nom_prog_en', 'nom_prog',
       'raison_prog_fr', 'agreement_title_en', 'titre_entente',
       'num_entente', 'valeur_entente', 'type_monnaie_étrangère',
       'valeur_monnaie_étrangère', 'date_début_entente', 'date_fin_entente',
       'couverture', 'description', 'identifiant_scian', 'résultats_attendus',
       'information_additionnelle', 'propriétaire_org', 'titre_propriétaire_org']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-a45fbcfb926a> in <module>
# ----> 1 sub = sub.columns['num_référence', 'num_amendement', 'date_amendement', 'type_entente',
#       2        'type_bénéficiaire', 'num_entreprise_beneficiaire', 'nom_legal_beneficiaire',
#       3        'nom_operation_beneficiaire', 'nom_organisation_recherche',
#       4        'pays_beneficiaire', 'province_beneficiaire', 'ville_beneficiaire',
#       5        'code_postal_beneficiaire', 'nom_circonscription_federale',
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    2093
#    2094         key = com._values_from_object(key)
# -> 2095         result = getitem(key)
#    2096         if not is_scalar(result):
#    2097             return promote(result)
#
# ...

# %%
sub.columns = ['num_référence', 'num_amendement', 'date_amendement', 'type_entente',
       'type_bénéficiaire', 'num_entreprise_beneficiaire', 'nom_legal_beneficiaire',
       'nom_operation_beneficiaire', 'nom_organisation_recherche',
       'pays_beneficiaire', 'province_beneficiaire', 'ville_beneficiaire',
       'code_postal_beneficiaire', 'nom_circonscription_federale',
       'num_circonscription_federale', 'nom_prog_en', 'nom_prog',
       'raison_prog_fr', 'agreement_title_en', 'titre_entente',
       'num_entente', 'valeur_entente', 'type_monnaie_étrangère',
       'valeur_monnaie_étrangère', 'date_début_entente', 'date_fin_entente',
       'couverture', 'description', 'identifiant_scian', 'résultats_attendus',
       'information_additionnelle', 'propriétaire_org', 'titre_propriétaire_org']

# %%
pd.set_option('display.max_columns', 500)

# %%
sub
# Out:
#                     num_référence  num_amendement date_amendement  \
# 0                GC-2017-Q1-00001               0             NaN
# 1                GC-2017-Q1-00002               0             NaN
# 2                GC-2017-Q1-00003               0             NaN
# 3                GC-2017-Q1-00004               0             NaN
# 4                GC-2017-Q1-00005               0             NaN
# 5                GC-2017-Q1-00006               0             NaN
# 6                GC-2017-Q1-00007               0             NaN
# 7                GC-2017-Q1-00008               0             NaN
# 8                GC-2017-Q2-00004               0             NaN
# 9                GC-2017-Q1-00009               0             NaN
# 10               GC-2017-Q1-00010               0             NaN
# 11               GC-2017-Q1-00011               0             NaN
# 12               GC-2017-Q1-00012               0             NaN
# ...

# %%
sub = sub.drop("agreement_title_en", 1)

# %%
sub.valeur_entente = sub.valeur_entente.str.replace("$","")

# %%
sub
# Out:
#                     num_référence  num_amendement date_amendement  \
# 0                GC-2017-Q1-00001               0             NaN
# 1                GC-2017-Q1-00002               0             NaN
# 2                GC-2017-Q1-00003               0             NaN
# 3                GC-2017-Q1-00004               0             NaN
# 4                GC-2017-Q1-00005               0             NaN
# 5                GC-2017-Q1-00006               0             NaN
# 6                GC-2017-Q1-00007               0             NaN
# 7                GC-2017-Q1-00008               0             NaN
# 8                GC-2017-Q2-00004               0             NaN
# 9                GC-2017-Q1-00009               0             NaN
# 10               GC-2017-Q1-00010               0             NaN
# 11               GC-2017-Q1-00011               0             NaN
# 12               GC-2017-Q1-00012               0             NaN
# ...

# %%
#Je viens de remarquer qu'il y a une consigne qui dit qu'on doit documenter nos actions... Je commmence ici!

# %%
#Je ne sais pas comment mieux nettoyer la colonne pour que celle-ci affiche un nombre décimal apprécié par pandas

# %%
sub.titre_propriétaire_org.value_counts()
# Out:
# Employment and Social Development Canada | Emploi et Développement social Canada                                                    58483
# Canadian Heritage | Patrimoine canadien                                                                                             48726
# Natural Sciences and Engineering Research Council of Canada | Conseil de recherches en sciences naturelles et en génie du Canada    26276
# National Research Council Canada | Conseil national de recherches Canada                                                            24403
# Canadian Institutes of Health Research | Instituts de recherche en santé du Canada                                                  15959
# Canada Economic Development for Quebec Regions | Développement économique Canada pour les régions du Québec                          8973
# Indigenous and Northern Affairs Canada | Affaires autochtones et du Nord Canada                                                      8527
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-856a6d9f5050> in <module>
# ----> 1 sub.groupby("Canadian Heritage | Patrimoine canadien  ")
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ...

# %%
sub.groupby("titre_propriétaire_org")

# %%
pat = sub.titre_propriétaire_org == "Canadian Heritage | Patrimoine canadien"

# %%
sub[pat]
# Out:
#                    num_référence  num_amendement date_amendement type_entente  \
# 165880          GC-2005-Q4-00001               0             NaN            C
# 165881          GC-2005-Q4-00002               0             NaN            C
# 165882          GC-2005-Q4-00003               0             NaN            C
# 165883          GC-2005-Q4-00004               0             NaN            C
# 165884          GC-2005-Q4-00005               0             NaN            C
# 165885          GC-2005-Q4-00006               0             NaN            C
# 165886          GC-2005-Q4-00007               0             NaN            C
# 165887          GC-2005-Q4-00008               0             NaN            C
# 165888          GC-2005-Q4-00045               0             NaN            C
# 165889          GC-2005-Q4-00009               0             NaN            C
# 165890          GC-2005-Q4-00010               0             NaN            C
# ...

# %%
#Je peux maintenant chercher à l'intérieur du ministère de pablo! yay!

# %%
sub[pat].nom_prog
# Out:
# 165880                                                  NaN
# 165881                                                  NaN
# 165882                                                  NaN
# 165883                                                  NaN
# 165884                                                  NaN
# 165885                                                  NaN
# 165886                                                  NaN
# 165887                                                  NaN
# 165888                                                  NaN
# 165889                                                  NaN
# 165890                                                  NaN
# 165891                                                  NaN
# 165892                                                  NaN
# 165893                                                  NaN
# 165894                                                  NaN
# 165895                                                  NaN
# ...

# %%
#Je remarque que les données des noms des programmes semblent parfois être attribuées à la colonne "raison_prog_fr", mais je fais peut-être erreur!

# %%
sub[pat].nom_prog.value_counts()
# Out:
# Fonds du Canada pour les périodiques                                    824
# Développement de Communautés de Langue Officielle                       461
# Développement des communautés par le biais des arts et du patrimoine    447
# Célébration, commémoration et apprentissage                             328
# Fonds du livre du Canada                                                298
# Programme du multiculturalisme                                          213
# Fonds du Canada pour la présentation des arts                           176
# Programme de soutien au sport                                           125
# Mise en valeur des langues officielles                                  120
# Programme des peuples autochtones                                       114
# Fonds du Canada pour les espaces Culturels                              105
# Sport - Programme d'accueil                                              75
# ...

# %%
#Wow, des subventions qui sauveront assurément les journaux du pays!

# %%
perio = sub.nom_prog == "Fonds du Canada pour les périodiques"

# %%
sub[perio].nom_legal_beneficiaire.value_counts()
# Out:
# SALTWIRE NETWORK INC. -  NEWFOUNDLAND                                          11
# SALTWIRE NETWORK INC.- NOVA SCOTIA                                              7
# GLACIER FARMMEDIA LIMITED PARTNERSHIP                                           5
# IQ BUSINESS MEDIA INC.                                                          4
# MAGAZINES CANADA                                                                4
# RAVEN MÉDIA INC.                                                                4
# ALTERNATIVES, INC.                                                              3
# ECOPARENT INC.                                                                  3
# CANADIAN SCRAPBOOKER INC.                                                       3
# GRASSLANDS NEWS GROUP                                                           3
# MÉDIAS TRANSCONTINENTAL S.E.N.C. / TRANSCONTINENTAL MEDIA G.P.                  3
# ...

# %%
sub[perio].nom_legal_beneficiaire.valeur_entente.sum().sort_values(ascending=False).head(
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-e9b7f9e5184d> in <module>
# ----> 1 sub[perio].nom_legal_beneficiaire.valeur_entente.sum().sort_values(ascending=False).head(10)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'valeur_entente'

# %%
periocash = perio.nomlegal_beneficiaire.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-6cf40f41f407> in <module>
# ----> 1 periocash = perio.nomlegal_beneficiaire.value_counts()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'nomlegal_beneficiaire'

# %%
periocash = perio.noml_egal_beneficiaire.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-9efc89b7b069> in <module>
# ----> 1 periocash = perio.noml_egal_beneficiaire.value_counts()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'noml_egal_beneficiaire'

# %%
periocash = perio.nom_legal_beneficiaire.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-ab46e31f9d05> in <module>
# ----> 1 periocash = perio.nom_legal_beneficiaire.value_counts()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'nom_legal_beneficiaire'

# %%
periocash = [sub]perio.nom_legal_beneficiaire.value_counts()
# Out:
#   File "<ipython-input-48-6fd38fce8b20>", line 1
#     periocash = [sub]perio.nom_legal_beneficiaire.value_counts()
#                          ^
# SyntaxError: invalid syntax

# %%
#Je bloque totalement ici... Je ne trouve aucune consigne dans le tutorial qui nous indique comment faire
#des sous ensembles plus poussés.. Je veux aller chercher le montant une liste des montants décroissante classée

# %%
#par le nom des entreprises qui, elles, ont reçu une subvention du programme du Fond du Canada pour les périodiques, mais
#Il ne semble pas exister d'exemple assez similaire dans le tutoriel pour que je réussisse et mes tentatives se sont avérées

# %%
#ratées! J'espère trouver la solution bientôt!
